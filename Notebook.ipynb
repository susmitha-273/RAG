# %%
from langchain_core.documents import Document
doc=Document(
    page_content='This is my first RAG Project',
    metadata={"Source":".\text.txt"}
)
print(doc)
# Out:
# page_content='This is my first RAG Project' metadata={'Source': '.\text.txt'}

# %%
print("Hello!")
# Out:
# Hello!
